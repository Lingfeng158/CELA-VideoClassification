# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from PIL import Image 
import numpy as np
filename = "temp.jpg"
image = Image.open(filename)
width, height = image.size 
data=image.getdata()

# %%
a=np.array(list(data))

# %%
a.shape
# Out:
# (59536, 3)

# %%
width
# Out:
# 244

# %%
b=a.reshape(width, height, 3)

# %%
b.shape
# Out:
# (244, 244, 3)

# %%
plt.imshow(b)

# %%
dir='/Users/lingfengli/Desktop/SIR/cela-tf-starter/ResizeBinnedToClips6F/Test/BLOOD-PRESSURE CUFF/S7/clip0'

# %%
import os
lst=os.listdir(dir)
len(lst)
# Out:
# 195
